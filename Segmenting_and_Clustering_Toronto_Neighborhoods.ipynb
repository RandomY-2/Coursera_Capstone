# %% [markdown]
# # Introduction
# In this notebook, I will scrape Toronto's postal code and neighborhood data from this Wikipedia site: https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M into a pandas dataframe. Furthermore, I will clean up the data by removing rows with missing data and combining rows that have the same postal code.

# %%
pip install lxml html5lib beautifulsoup4

# %% [markdown]
# # Web Sraping Toronto Neighborhoods from Wikipedia using Pandas
# First, I will use Pandas to read the data from web into a dataframe.

# %%
import pandas as pd

url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
dfs = pd.read_html(url)

# %% [markdown]
# What we need is the first dataframe

# %%
dfs[0]
# Out:
#     Postal Code  ...                                      Neighbourhood
# 0           M1A  ...                                       Not assigned
# 1           M2A  ...                                       Not assigned
# 2           M3A  ...                                          Parkwoods
# 3           M4A  ...                                   Victoria Village
# 4           M5A  ...                          Regent Park, Harbourfront
# ..          ...  ...                                                ...
# 175         M5Z  ...                                       Not assigned
# 176         M6Z  ...                                       Not assigned
# 177         M7Z  ...                                       Not assigned
# 178         M8Z  ...  Mimico NW, The Queensway West, South of Bloor,...
# 179         M9Z  ...                                       Not assigned
#
# [180 rows x 3 columns]

# %%
dfs[0].shape
# Out:
# (180, 3)

# %%
dfs[0].columns
# Out:
# Index(['Postal Code', 'Borough', 'Neighbourhood'], dtype='object')

# %% [markdown]
# # Data Wrangling

# %% [markdown]
# **Drop rows that have 'Not assigned' for Borough column**
#
# Now, I will remove rows that have missing borough data, which are ultimately too unconvenient to be imputed.

# %%
dfs[0] = dfs[0][dfs[0]['Borough'] != 'Not assigned']

# %%
dfs[0].shape
# Out:
# (103, 3)

# %%
dfs[0].head()
# Out:
#   Postal Code           Borough                                Neighbourhood
# 2         M3A        North York                                    Parkwoods
# 3         M4A        North York                             Victoria Village
# 4         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 5         M6A        North York             Lawrence Manor, Lawrence Heights
# 6         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government

# %% [markdown]
# **Combine rows that have the same postal code**
#
# In this section, I will combien rows that share the same postal code.

# %%
dfs[0] = dfs[0].groupby(['Postal Code']).first()

# %%
dfs[0].head()
# Out:
#                  Borough                           Neighbourhood
# Postal Code
# M1B          Scarborough                          Malvern, Rouge
# M1C          Scarborough  Rouge Hill, Port Union, Highland Creek
# M1E          Scarborough       Guildwood, Morningside, West Hill
# M1G          Scarborough                                  Woburn
# M1H          Scarborough                               Cedarbrae

# %%
dfs[0].columns
# Out:
# Index(['Borough', 'Neighbourhood'], dtype='object')

# %% [markdown]
# we see now postal code becomes the index instead a regular column. So let's reset it to a column

# %%
dfs[0] = dfs[0].reset_index()

# %%
dfs[0].head()
# Out:
#   Postal Code      Borough                           Neighbourhood
# 0         M1B  Scarborough                          Malvern, Rouge
# 1         M1C  Scarborough  Rouge Hill, Port Union, Highland Creek
# 2         M1E  Scarborough       Guildwood, Morningside, West Hill
# 3         M1G  Scarborough                                  Woburn
# 4         M1H  Scarborough                               Cedarbrae

# %% [markdown]
# let's quickly check if the code is doing the right thing.

# %%
dfs[0][dfs[0]['Postal Code'] == 'M5A']
# Out:
#    Postal Code           Borough              Neighbourhood
# 53         M5A  Downtown Toronto  Regent Park, Harbourfront

# %% [markdown]
# **Make 'Not assigned' Neighbourhood same as borough**
#
# The last step of our wrangling is to use borough to fill missing neighborhoods. However, since there is no such missing value, we don't need to do anything.

# %%
dfs[0][dfs[0]['Neighbourhood'] == 'Not assigned']
# Out:
# Empty DataFrame
# Columns: [Postal Code, Borough, Neighbourhood]
# Index: []

# %% [markdown]
# **Final View of Data after Wrangling(End of Part 1)**

# %%
toronto_neighborhoods = dfs[0]

toronto_neighborhoods.head()
# Out:
#   Postal Code      Borough                           Neighbourhood
# 0         M1B  Scarborough                          Malvern, Rouge
# 1         M1C  Scarborough  Rouge Hill, Port Union, Highland Creek
# 2         M1E  Scarborough       Guildwood, Morningside, West Hill
# 3         M1G  Scarborough                                  Woburn
# 4         M1H  Scarborough                               Cedarbrae

# %%
toronto_neighborhoods.shape
# Out:
# (103, 3)

# %% [markdown]
# # Acquire Location of Neighborhoods
# Now we have cleaned our data, let's get the longitude and latitude of each row

# %%
pip install geocoder
# Out:
# ...
#      |████████████████████████████████| 102kB 5.8MB/s
# ...

# %%
import geocoder

# %%
'''
latitudes = []
longitudes = []

for index, row in toronto_neighborhoods.iterrows():
  postal_code = row['Postal Code']  
  lat_lng_coords = None
  print(index)
  while(lat_lng_coords is None):
    g = geocoder.google('{}, Toronto, Ontario'.format(postal_code))
    lat_lng_coords = g.latlng

  latitude = lat_lng_coords[0]
  longitude = lat_lng_coords[1]

  latitudes.append(latitude)
  longitude.append(longitude)

print(latitudes)
print(longitudes)
'''
# Out:
# "\nlatitudes = []\nlongitudes = []\n\nfor index, row in toronto_neighborhoods.iterrows():\n  postal_code = row['Postal Code']  \n  lat_lng_coords = None\n  print(index)\n  while(lat_lng_coords is None):\n    g = geocoder.google('{}, Toronto, Ontario'.format(postal_code))\n    lat_lng_coords = g.latlng\n\n  latitude = lat_lng_coords[0]\n  longitude = lat_lng_coords[1]\n\n  latitudes.append(latitude)\n  longitude.append(longitude)\n\nprint(latitudes)\nprint(longitudes)\n"

# %% [markdown]
# geocoder is not working. So I will just use a csv that contains latitudes and longitudes

# %%
url = 'http://cocl.us/Geospatial_data'

location_data = pd.read_csv(url)

# %%
location_data.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
location_data.shape
# Out:
# (103, 3)

# %%
toronto_neighborhoods = toronto_neighborhoods.join(location_data.set_index('Postal Code'), on='Postal Code')

# %% [markdown]
# **View of Appended Data(End of Part2)**

# %%
toronto_neighborhoods
# Out:
#     Postal Code      Borough  ...   Latitude  Longitude
# 0           M1B  Scarborough  ...  43.806686 -79.194353
# 1           M1C  Scarborough  ...  43.784535 -79.160497
# 2           M1E  Scarborough  ...  43.763573 -79.188711
# 3           M1G  Scarborough  ...  43.770992 -79.216917
# 4           M1H  Scarborough  ...  43.773136 -79.239476
# ..          ...          ...  ...        ...        ...
# 98          M9N         York  ...  43.706876 -79.518188
# 99          M9P    Etobicoke  ...  43.696319 -79.532242
# 100         M9R    Etobicoke  ...  43.688905 -79.554724
# 101         M9V    Etobicoke  ...  43.739416 -79.588437
# 102         M9W    Etobicoke  ...  43.706748 -79.594054
#
# [103 rows x 5 columns]

# %% [markdown]
# # Neighborhood Visualization
# In this section, I will visualize the location of each neighborhood and explore what venues are around each location using Foursquaure

# %% [markdown]
# **Visualize the locations**
#
# Before we begin clustering, let's actually see the locations we have on a map. I will achieve this using geocoder and folium libraries.

# %%
import geocoder
from geopy.geocoders import Nominatim 

address = 'Toronto, Ontario'

geolocator = Nominatim(user_agent="toronto_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto are 43.6534817, -79.3839347.

# %%
import folium

map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(toronto_neighborhoods['Latitude'], toronto_neighborhoods['Longitude'], toronto_neighborhoods['Borough'], toronto_neighborhoods['Neighbourhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.co
# ...

# %% [markdown]
# **FourSquare Credentials**

# %%
CLIENT_ID = 'ETHN0R5XOJAAJENV4MDYBUT55TKFM5GOEL0SXAXEHOHOOR3W'
CLIENT_SECRET = '0GXI3BRZ2EYH1QCSVHRA2CK53K2LLCNMQ5XZSXVMYH44KAJL'
VERSION = '20180605' # Foursquare API version
LIMIT = 100 # A default Foursquare API limit value

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: ETHN0R5XOJAAJENV4MDYBUT55TKFM5GOEL0SXAXEHOHOOR3W
# CLIENT_SECRET:0GXI3BRZ2EYH1QCSVHRA2CK53K2LLCNMQ5XZSXVMYH44KAJL

# %% [markdown]
# **Explore the first location**
#
# Just for curiosity, let's explore the first location in our data

# %% [markdown]
# Get the neighborhood's name.

# %%
toronto_neighborhoods.loc[0, 'Neighbourhood']
# Out:
# 'Malvern, Rouge'

# %% [markdown]
# Get the neighborhood's latitude and longitude values.

# %%
neighborhood_latitude = toronto_neighborhoods.loc[0, 'Latitude'] # neighborhood latitude value
neighborhood_longitude = toronto_neighborhoods.loc[0, 'Longitude'] # neighborhood longitude value

neighborhood_name = toronto_neighborhoods.loc[0, 'Neighbourhood'] # neighborhood name

print('Latitude and longitude values of {} are {}, {}.'.format(neighborhood_name, neighborhood_latitude, neighborhood_longitude))
# Out:
# Latitude and longitude values of Malvern, Rouge are 43.806686299999996, -79.19435340000001.

# %% [markdown]
# **Top 5 venues that are in Malvern Rouge within a radius of 500 meters.**

# %%
LIMIT = 5
radius = 500

url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighborhood_latitude, 
    neighborhood_longitude, 
    radius, 
    LIMIT)

# %%
import json
import requests

results = requests.get(url).json()

# %%
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
from pandas.io.json import json_normalize

venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
#       name            categories        lat        lng
# 0  Wendy’s  Fast Food Restaurant  43.807448 -79.199056

# %% [markdown]
# Well, I guess there isn't many venues around Malvern, Rouge

# %% [markdown]
# **Nearby Venues in Toronto**
#
# Now, let us generalize our finding to entire Toronto

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighbourhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
toronto_venues = getNearbyVenues(names=toronto_neighborhoods['Neighbourhood'],
                                   latitudes=toronto_neighborhoods['Latitude'],
                                   longitudes=toronto_neighborhoods['Longitude']
                                  )
# Out:
# Malvern, Rouge
# Rouge Hill, Port Union, Highland Creek
# Guildwood, Morningside, West Hill
# Woburn
# Cedarbrae
# Scarborough Village
# Kennedy Park, Ionview, East Birchmount Park
# Golden Mile, Clairlea, Oakridge
# Cliffside, Cliffcrest, Scarborough Village West
# Birch Cliff, Cliffside West
# Dorset Park, Wexford Heights, Scarborough Town Centre
# Wexford, Maryvale
# Agincourt
# Clarks Corners, Tam O'Shanter, Sullivan
# Milliken, Agincourt North, Steeles East, L'Amoreaux East
# Steeles West, L'Amoreaux West
# Upper Rouge
# Hillcrest Village
# Fairview, Henry Farm, Oriole
# Bayview Village
# York Mills, Silver Hills
# Willowdale, Newtonbrook
# Willowdale, Willowdale East
# York Mills West
# Willowdale, Willowdale West
# Parkwoods
# Don Mills
# Don Mills
# Bathurst Manor, Wilson Heights, Downsview North
# Northwood Park, York University
# Downsview
# Downsview
# Downsview
# Downsview
# Victoria Village
# Parkview Hill, Woodbine Gardens
# Woodbine Heights
# The Beaches
# Leaside
# ...

# %% [markdown]
# **Examine the Result**

# %% [markdown]
# 1. Size of the resulting dataframe

# %%
print(toronto_venues.shape)
toronto_venues.head()
# Out:
# (429, 7)
#                             Neighbourhood  ...              Venue Category
# 0                          Malvern, Rouge  ...        Fast Food Restaurant
# 1  Rouge Hill, Port Union, Highland Creek  ...                 Golf Course
# 2  Rouge Hill, Port Union, Highland Creek  ...  Construction & Landscaping
# 3  Rouge Hill, Port Union, Highland Creek  ...                         Bar
# 4       Guildwood, Morningside, West Hill  ...                        Bank
#
# [5 rows x 7 columns]

# %% [markdown]
# 2. Number of venues returned for each neighborhood

# %%
toronto_venues.groupby('Neighbourhood').count()
# Out:
#                                                  Neighborhood Latitude  ...  Venue Category
# Neighbourhood                                                           ...
# Agincourt                                                            5  ...               5
# Alderwood, Long Branch                                               5  ...               5
# Bathurst Manor, Wilson Heights, Downsview North                      5  ...               5
# Bayview Village                                                      4  ...               4
# Bedford Park, Lawrence Manor East                                    5  ...               5
# ...                                                                ...  ...             ...
# Willowdale, Willowdale East                                          5  ...               5
# Willowdale, Willowdale West                                          5  ...               5
# ...

# %% [markdown]
# 3. Number of unique categories can be curated from all the returned venues

# %%
print('There are {} uniques categories.'.format(len(toronto_venues['Venue Category'].unique())))
# Out:
# There are 143 uniques categories.

# %% [markdown]
# # Neighborhood Clustering
#
# Now, I will use K-Means to cluster the locations into 5 groups

# %%
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
toronto_onehot['Neighbourhood'] = toronto_venues['Neighbourhood'] 

# move neighborhood column to the first column
fixed_columns = [toronto_onehot.columns[-1]] + list(toronto_onehot.columns[:-1])
manhattan_onehot = toronto_onehot[fixed_columns]

toronto_onehot.head()
# Out:
#    Airport  ...                           Neighbourhood
# 0        0  ...                          Malvern, Rouge
# 1        0  ...  Rouge Hill, Port Union, Highland Creek
# 2        0  ...  Rouge Hill, Port Union, Highland Creek
# 3        0  ...  Rouge Hill, Port Union, Highland Creek
# 4        0  ...       Guildwood, Morningside, West Hill
#
# [5 rows x 144 columns]

# %%
toronto_onehot.shape
# Out:
# (429, 144)

# %%
toronto_grouped = toronto_onehot.groupby('Neighbourhood').mean().reset_index()
toronto_grouped
# Out:
#                                       Neighbourhood  ...  Yoga Studio
# 0                                         Agincourt  ...          0.0
# 1                            Alderwood, Long Branch  ...          0.0
# 2   Bathurst Manor, Wilson Heights, Downsview North  ...          0.0
# 3                                   Bayview Village  ...          0.0
# 4                 Bedford Park, Lawrence Manor East  ...          0.0
# ..                                              ...  ...          ...
# 91                      Willowdale, Willowdale East  ...          0.0
# 92                      Willowdale, Willowdale West  ...          0.0
# 93                                           Woburn  ...          0.0
# 94                                 Woodbine Heights  ...          0.0
# 95                                  York Mills West  ...          0.0
#
# [96 rows x 144 columns]

# %%
toronto_grouped.shape
# Out:
# (96, 144)

# %%
num_top_venues = 5

for hood in toronto_grouped['Neighbourhood']:
    print("----"+hood+"----")
    temp = toronto_grouped[toronto_grouped['Neighbourhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Agincourt----
#                        venue  freq
# 0             Breakfast Spot   0.2
# 1  Latin American Restaurant   0.2
# 2               Skating Rink   0.2
# 3             Clothing Store   0.2
# 4                     Lounge   0.2
#
#
# ----Alderwood, Long Branch----
#          venue  freq
# 0  Pizza Place   0.4
# 1          Gym   0.2
# 2  Coffee Shop   0.2
# 3          Pub   0.2
# 4        Motel   0.0
#
#
# ----Bathurst Manor, Wilson Heights, Downsview North----
#                        venue  freq
# 0                Bridal Shop   0.2
# 1                 Restaurant   0.2
# 2                Coffee Shop   0.2
# 3  Middle Eastern Restaurant   0.2
# 4              Deli / Bodega   0.2
#
#
# ----Bayview Village----
#                  venue  freq
# 0                 Bank  0.25
# 1                 Café  0.25
# 2  Japanese Restaurant  0.25
# 3   Chinese Restaurant  0.25
# 4        Movie Theater  0.00
#
#
# ----Bedford Park, Lawrence Manor East----
#                 venue  freq
# ...

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
import numpy as np 

num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighbourhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
toronto_venues_sorted = pd.DataFrame(columns=columns)
toronto_venues_sorted['Neighbourhood'] = toronto_grouped['Neighbourhood']

for ind in np.arange(toronto_grouped.shape[0]):
    toronto_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

toronto_venues_sorted.head()
# Out:
#                                      Neighbourhood  ... 10th Most Common Venue
# 0                                        Agincourt  ...           Concert Hall
# 1                           Alderwood, Long Branch  ...                  Diner
# 2  Bathurst Manor, Wilson Heights, Downsview North  ...            Yoga Studio
# 3                                  Bayview Village  ...           Dessert Shop
# 4                Bedford Park, Lawrence Manor East  ...       Department Store
#
# [5 rows x 11 columns]

# %%
from sklearn.cluster import KMeans

kclusters = 5

toronto_grouped_clustering = toronto_grouped.drop('Neighbourhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([0, 4, 2, 0, 0, 0, 0, 2, 4, 0], dtype=int32)

# %%
# add clustering labels
toronto_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

toronto_merged = toronto_neighborhoods

# merge manhattan_grouped with manhattan_data to add latitude/longitude for each neighborhood
toronto_merged = toronto_merged.join(toronto_venues_sorted.set_index('Neighbourhood'), on='Neighbourhood')

toronto_merged.head() # check the last columns!
# Out:
#   Postal Code      Borough  ... 9th Most Common Venue  10th Most Common Venue
# 0         M1B  Scarborough  ...      Department Store           Deli / Bodega
# 1         M1C  Scarborough  ...                 Diner            Dessert Shop
# 2         M1E  Scarborough  ...          Dessert Shop        Department Store
# 3         M1G  Scarborough  ...          Dessert Shop           Deli / Bodega
# 4         M1H  Scarborough  ...                 Diner            Dessert Shop
#
# [5 rows x 16 columns]

# %%
toronto_merged['Cluster Labels'] = toronto_merged['Cluster Labels'].fillna(0)

# %%
import matplotlib.cm as cm
import matplotlib.colors as colors

# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Neighbourhood'], toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[int(cluster-1)],
        fill=True,
        fill_color=rainbow[int(cluster-1)],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.co
# ...
